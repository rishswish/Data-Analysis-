# %% [markdown]
# <a href="https://colab.research.google.com/github/rishswish/Data-Analysis-/blob/main/Copy_of_Copy_of_new_yolo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15637, done.
# remote: Counting objects: 100% (244/244), done.
# remote: Compressing objects: 100% (147/147), done.
# remote: Total 15637 (delta 123), reused 169 (delta 97), pack-reused 15393
# Receiving objects: 100% (15637/15637), 14.64 MiB | 24.22 MiB/s, done.
# Resolving deltas: 100% (10651/10651), done.

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
# !unzip -q ../Yawn_everyone_data.zip -d ../

# %%
# %cd /content/yolov5
# Out:
# /content/yolov5

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/hub.py:286: UserWarning: You are about to download and run code from an untrusted repository. In a future release, this won't be allowed. To add the repository to your trusted list, change the command to {calling_fn}(..., trust_repo=False) and a command prompt will appear asking for an explicit confirmation of trust, or load(..., trust_repo=True), which will assume that the prompt is to be answered with 'yes'. You can also use load(..., trust_repo='check') which will only prompt for confirmation if the repo is not already trusted. This will eventually be the default behaviour
#   warnings.warn(
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-5 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.
# ...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 135MB/s]
#
# Fusing layers...
# ...

# %%
# !python train.py --img 320 --batch 16 --epochs 1000 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --workers 2
# Out:
# train: weights=yolov5s.pt, cfg=, data=/content/yolov5/data/custom_data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=1000, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %%
import uuid   # Unique identifier
import os
import time

# %%
cd ..
# Out:
# /

# %%
img = os.path.join('content', '/Yawn_everyone_data/data/images/', 'yawn.2138f47e-eb22-11ed-b7a3-83bde209a317.jpg')

# %%
model = torch.hub.load('ultralytics/yolov5', 'custom', path='/content/yolov5/runs/train/exp2/weights/last.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to /root/.cache/torch/hub/master.zip
# YOLOv5 🚀 2023-5-5 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients
# Adding AutoShape...
# requirements: /root/.cache/torch/hub/requirements.txt not found, check failed.

# %%
results = model(img)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-c87f9d4e9ddf> in <cell line: 1>()
# ----> 1 results = model(img)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1499                 or _global_backward_pre_hooks or _global_backward_hooks
#    1500                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501             return forward_call(*args, **kwargs)
#    1502         # Do not call functions when jit is used
#    1503         full_backward_hooks, non_full_backward_hooks = [], []
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     113     def decorate_context(*args, **kwargs):
#     114         with ctx_factory():
# --> 115             return func(*args, **kwargs)
#     116
# ...

# %%
results.print()
# Out:
# image 1/1: 480x640 1 yawn
# Speed: 20.4ms pre-process, 2974.8ms inference, 2.5ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
img = os.path.join('content', '/yawn_noyawn_train_data/data/images/train', 'no_yawn.d751e4ce-d2db-11ed-a9b9-8bee50b93f35.jpg')

# %%
results = model(img)

# %%
results.print()
# Out:
# image 1/1: 480x640 1 no_yawn
# Speed: 14.7ms pre-process, 13.1ms inference, 1.4ms NMS per image at shape (1, 3, 480, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
 # !zip -r yawn_analysis.zip /content/yolov5/runs/train/exp2/weights
# Out:
#   adding: content/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/weights/last.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/weights/best.pt (deflated 8%)

# %%
# !zip -r /content/yolov5/runs/train/exp2.zip /content/yolov5/runs/train/exp2
# Out:
#   adding: content/yolov5/runs/train/exp2/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/train_batch2.jpg (deflated 3%)
#   adding: content/yolov5/runs/train/exp2/events.out.tfevents.1683287848.95db867717f2.8955.0 (deflated 86%)
#   adding: content/yolov5/runs/train/exp2/labels.jpg (deflated 30%)
#   adding: content/yolov5/runs/train/exp2/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp2/train_batch0.jpg (deflated 2%)
#   adding: content/yolov5/runs/train/exp2/labels_correlogram.jpg (deflated 44%)
#   adding: content/yolov5/runs/train/exp2/results.csv (deflated 84%)
#   adding: content/yolov5/runs/train/exp2/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp2/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp2/weights/best.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/weights/last.pt (deflated 8%)
#   adding: content/yolov5/runs/train/exp2/train_batch1.jpg (deflated 3%)
